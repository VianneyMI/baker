# %%
import os
import json
from pathlib import Path

import certifi

from pymongo import MongoClient
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
os.getenv("MONGODB_SERVER")
# Out:
# 'mongodb+srv://vianmixt:9wNPfBSF2Idqr3RF@cluster0.xciie.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
client = MongoClient(os.getenv("MONGODB_SERVER"), tlsCAFile=certifi.where())

# %%
db = client["baker"]
db["recipes"].insert_one({"message": "test"})
# Out:
# InsertOneResult(ObjectId('670eab49816c308235724d26'), acknowledged=True)

# %%
os.getcwdb()
# Out:
# b'/Users/vianneymixtur/CustomDesktop/exploration/baker'

# %%
__file__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 __file__
#
# NameError: name '__file__' is not defined

# %%
path_to_data = Path(os.getcwd()) / "data"

# %%
with open(path_to_data / "output" / "parsed_recipes_all_8x7b.json") as f:
    recipes = json.load(f)

# %%
recipes[0]
# Out:
# {'recipe_id': 0,
#  'original_title': 'Creamy Mashed Potatoes',
#  'name': 'Loaded Mashed Potatoes',
#  'serving_size': 4,
#  'ingredients': [{'id': 1,
#    'name': 'potatoes',
#    'quantity': 1000.0,
#    'unit': 'grams'},
#   {'id': 2, 'name': 'milk', 'quantity': 200.0, 'unit': 'milliliters'},
#   {'id': 3, 'name': 'mayonnaise', 'quantity': 200.0, 'unit': 'milliliters'},
#   {'id': 4, 'name': 'cheese', 'quantity': 100.0, 'unit': 'grams'},
#   {'id': 5, 'name': 'garlic powder', 'quantity': None, 'unit': None},
#   {'id': 6, 'name': 'bacon', 'quantity': None, 'unit': None},
#   {'id': 7, 'name': 'butter', 'quantity': None, 'unit': None},
#   {'id': 8, 'name': 'green onions', 'quantity': None, 'unit': None},
#   {'id': 9, 'name': 'black pepper', 'quantity': None, 'unit': None},
#   {'id': 10, 'name': 'salt', 'quantity': None, 'unit': None}],
#  'steps': [{'number': 1,
#    'description': 'Peel and cut the potatoes into medium sized pieces.',
#    'preparation_time': 10.0,
# ...

# %%
db["recipes"].insert_many(recipes)
# Out:
# InsertManyResult([ObjectId('670eac5f816c308235724d27'), ObjectId('670eac5f816c308235724d28'), ObjectId('670eac5f816c308235724d29'), ObjectId('670eac5f816c308235724d2a'), ObjectId('670eac5f816c308235724d2b'), ObjectId('670eac5f816c308235724d2c'), ObjectId('670eac5f816c308235724d2d'), ObjectId('670eac5f816c308235724d2e'), ObjectId('670eac5f816c308235724d2f'), ObjectId('670eac5f816c308235724d30'), ObjectId('670eac5f816c308235724d31'), ObjectId('670eac5f816c308235724d32'), ObjectId('670eac5f816c308235724d33'), ObjectId('670eac5f816c308235724d34'), ObjectId('670eac5f816c308235724d35'), ObjectId('670eac5f816c308235724d36'), ObjectId('670eac5f816c308235724d37'), ObjectId('670eac5f816c308235724d38'), ObjectId('670eac5f816c308235724d39'), ObjectId('670eac5f816c308235724d3a'), ObjectId('670eac5f816c308235724d3b'), ObjectId('670eac5f816c308235724d3c'), ObjectId('670eac5f816c308235724d3d'), ObjectId('670eac5f816c308235724d3e'), ObjectId('670eac5f816c308235724d3f'), ObjectId('670eac5f816c30823572
# ...

# %%
cursor = db["recipes"].find(
    {
        "serving_size": 4,
        "ingredients.name": "potatoes",
        "ingredients.quantity": {"$lt": 4},
        "ingredients.unit": "unit",
    }
)
results = list(cursor)
len(results)
# Out:
# 9

# %%
results
# Out:
# [{'_id': ObjectId('670eac5f816c308235724d97'),
#   'recipe_id': 112,
#   'original_title': 'Slow-cooked Lamb with Lemon',
#   'name': 'Slow-Cooked Lamb Shoulder with Garlic and Lemon',
#   'serving_size': 4,
#   'ingredients': [{'id': 1,
#     'name': 'lamb shoulder',
#     'quantity': 2.2,
#     'unit': 'kg'},
#    {'id': 2, 'name': 'olive oil', 'quantity': 2.0, 'unit': 'tablespoons'},
#    {'id': 3, 'name': 'lemon', 'quantity': 1.0, 'unit': 'unit'},
#    {'id': 4, 'name': 'garlic', 'quantity': 1.0, 'unit': 'head'},
#    {'id': 5, 'name': 'carrots', 'quantity': 2.0, 'unit': 'unit'},
#    {'id': 6, 'name': 'leek', 'quantity': 1.0, 'unit': 'unit'},
#    {'id': 7, 'name': 'onion', 'quantity': 1.0, 'unit': 'unit'},
#    {'id': 8, 'name': 'oregano', 'quantity': 1.0, 'unit': 'teaspoon'},
#    {'id': 9, 'name': 'rosemary', 'quantity': 1.0, 'unit': 'teaspoon'},
#    {'id': 10, 'name': 'potatoes', 'quantity': 4.0, 'unit': 'unit'},
# ...
