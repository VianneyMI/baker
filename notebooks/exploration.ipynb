# %%
import os
import json

import pandas as pd
from langchain.output_parsers import PydanticOutputParser
from langchain_mistralai.chat_models import ChatMistralAI

from dotenv import load_dotenv
from baker.parser import RecipeParser, MESSAGE, CHAT_PROMPT_TEMPLATE
from baker.schemas import Recipe
# Out:
# /Users/vianneymixtur/CustomDesktop/exploration/baker/.venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import ChatOpenAI`.
#   warn_deprecated(

# %%
df = pd.read_json("data/recipes_v1_with_token_counts.json")
df.head()
# Out:
#                            title       date                         tags  \
# 0         Creamy Mashed Potatoes 2021-03-12   [potato, side, cheesefare]
# 1  Red Sauce (Ragu all'Italiana) 2021-03-16             [italian, sauce]
# 2             Turmeric Flatbread 2022-08-09             [bread, turkish]
# 3        Zurich-Style Meat Saute 2023-01-06  [beef, cream, swiss, quick]
# 4        Tuscan Style Pork Roast 2021-03-10       [italian, pork, roast]
#
#                                         introduction  \
# 0  ![Creamy Mashed Potatoes](/pix/creamy-mashed-p...
# 1  My great-grandma's red sauce. All purpose: goo...
# 2  A great companion to Turkish Red Lentil Soup. ...
# 3  Originally called "Züri Gschnätzlets" (Zurich ...
# 4  ![tuscan-style-pork-roast](/pix/tuscan-style-p...
#
#                                          ingredients  \
# 0  The quantities here are for about four adult p...
# 1  - 1/3 lb salt pork - 2 lb chuck roast - 3 Clov...
# 2  - 1 cup Wheat Flour (white or whole) - 1/2 Tbs...
# 3  - 600g\tBeef, finely sliced - 250g\tMushrooms,...
# 4  - 1 pork Roast - 2-3 Tbsp fresh rosemary - 8 c...
#
#                                            direction  \
# 0  1. Peel and cut the potatoes into medium sized...
# 1  1. Mince the garlic, peel the carrot, peel and...
# 2  1. Combine flour, turmeric, salt and baking po...
# 3  1. Fry the meat in butter at high heat until i...
# 4  1.\tPreheat oven to 275°F (135°C) 2.\tButterfl...
#
#                                               output  ingredients_count  \
# 0  {'title': 'Creamy Mashed Potatoes', 'ingredien...                 93
# 1  {'title': 'Red Sauce (Ragu all'Italiana)', 'in...                 61
# 2  {'title': 'Turmeric Flatbread', 'ingredients':...                 30
# 3  {'title': 'Zurich-Style Meat Saute', 'ingredie...                 37
# 4  {'title': 'Tuscan Style Pork Roast', 'ingredie...                 38
#
#    direction_count
# 0              184
# 1              117
# 2               90
# 3              126
# 4              473

# %%
MISTRAL_API_KEY = os.getenv("MISTRAL_API_KEY")

# %%
llm = ChatMistralAI(api_key=MISTRAL_API_KEY, model_name="open-mixtral-8x7b")
parser = PydanticOutputParser(pydantic_object=Recipe)

# %%
recipe_parser = RecipeParser(llm=llm, parser=parser)

# %%
df["ingredients"][0]
# Out:
# 'The quantities here are for about four adult portions. If you are planning on eating this as a side dish, it might be more like 6-8 portions. * 1kg potatoes * 200ml milk* * 200ml mayonnaise* * ~100g cheese * Garlic powder * 12-16 strips of bacon * Butter * 3-4 green onions * Black pepper * Salt  *You can play with the proportions depending on how creamy or dry you want the mashed potatoes to be.'

# %%
df["title"].to_list()
# Out:
# ['Creamy Mashed Potatoes',
#  "Red Sauce (Ragu all'Italiana)",
#  'Turmeric Flatbread',
#  'Zurich-Style Meat Saute',
#  'Tuscan Style Pork Roast',
#  'Smoked Salmon Pasta Primavera',
#  'Spicy Mayo',
#  'Risengrød',
#  'Pilaf',
#  'Italian Bread',
#  'Pancake',
#  'Tanzanian Tea w/ Milk',
#  'Cheesy Potato Bake',
#  'Spaghetti aglio e olio',
#  'Quarkbällchen – Fried curd balls',
#  'Mapo Tofu (麻婆豆腐)',
#  'Chili Con Carne',
#  'Liver and Onions',
#  'Korv Stroganoff',
#  'Naan Bread',
#  'Steak Tartare',
#  'Hangover Eggs',
#  'Baked Salmon',
#  'Oatmeal Cookies',
#  'Spiced Apple Pancakes',
#  'Beef Jerky',
#  'Onion Raitha (Indian Tzatziki)',
#  'Cheese',
#  'Ravioli',
#  'Italian Mulled Wine',
#  'Refried Beans',
#  'Fall Vegetable and Chickpea Curry',
#  'Winter Risotto',
#  'Parmesan potatoes',
#  'Swedish Pancakes',
#  'Chicken Parmesan',
#  'Red Bean Buns (豆沙包)',
#  'Omelet',
#  'Aussie Snags (sausage sizzle)',
#  'Bitoque - Portuguese Steak with Beer Sauce',
#  'Lasagna',
#  'Irish Potato Casserole',
#  'Greek Yogurt',
#  'Tabouleh',
#  'Dried tomato & plum bread spread',
#  'Shrimp and Grits',
#  'Cuca Italiana',
#  'Frittata',
#  'Panang-Style Beef Curry',
#  'Chipolata Sausage in Balsamic Vinegar',
#  'Zopf',
#  'Ricotta',
#  'Asian Style Chicken with Sticky Sauce',
#  "'Shrimp Fettuccine Alfredo'",
#  'Caesar Salad',
#  'Miso-soup',
#  'Pan-seared Chicken Fillet',
#  'Soleier (pickled eggs)',
#  'Chorizo & Chickpea Soup',
#  'Fresh Guacamole',
#  'Blueberry Muffins',
#  'Pasta Arrabbiata',
#  'Bloody Mary Mix',
#  'Mexican Meat Loaf',
#  'Stoemp',
#  'Torrijas',
#  'Ham and Lentil Soup',
#  'Hamburger Patties',
#  'Tomato Flavored Hamburger and Macaroni',
#  'Oatmeal Pancakes',
#  'Quiche Lorraine - Lothringer Käsetorte',
#  'Cheesy Meatballs with Tomato Sauce',
#  'Loaded Mexican Rice',
#  'Croque-monsieur bites',
#  'Wholemeal Wheat Flour Pizza Dough',
#  'Danish Pancake',
#  'Eggs',
#  'Slow-cooked Chicken Tacos',
#  'Keto Coconut Bread',
#  'Honey Sriracha Chicken Thighs',
#  'Three Bean Salad',
#  'Matcha Cookies',
#  'Pizza sauce',
#  'French Crêpes',
#  'Yibin Burning Noodles',
#  'Easy Pizza Sauce',
#  'Bread',
#  'Sticky Porkchops',
#  "'Kombucha'",
#  'Shakshouka',
#  'Hoisin Pork Belly',
#  'Apple Chicken',
#  'Pepper Sauce',
#  'Drunken beans (Pintos Borrachos)',
#  'Ginataang Kalabasa',
#  'Kvass',
#  'Sourdough Table Loaf',
#  'Potato Soup',
#  'Fried Anglerfish fillet',
#  'Basic Sweet Potato Fries Recipe',
#  'Teriyaki Beef Wok',
#  'Baked pasta with broccoli, boiled eggs and scamorza cheese',
#  'Easy Chicken and Rice Casserole',
#  'Frijol con puerco',
#  'Beef Wellington',
#  'Gypsy Soup',
#  'Ragù',
#  'Lebanese Lentil Soup',
#  'Ragu Napoletano',
#  'Torta Frita Criolla (Argentinian frybread)',
#  'Salsa Verde',
#  'Limoncello',
#  'Slow-cooked Lamb with Lemon',
#  'Tofu Stir Fry',
#  'Ukrainian Vareniki',
#  'Pho Soup',
#  'Cheesy Pasta Bake',
#  'Sourdough bread with seeds and grains',
#  'Spatchcock Chicken',
#  'Smoked Turkey',
#  'Almeirim Stone Soup',
#  'Medieval Beef Soup',
#  "Schinkenfleckerl überbacken, Viennese Mac'n'Cheese",
#  "'Kettle Chips'",
#  'Rösti',
#  'Country Crisp Cereals',
#  'Okonomiyaki',
#  "'Butter-based biscuit and cookies'",
#  'Spinach-Rice Casserole',
#  'Beef Tips in Gravy on Sour Cream Mashed Potatoes',
#  'Beef and Broccoli',
#  'French mustard sauce porkchops (Côtes de porc charcutières)',
#  'Southern Biscuits',
#  "Za'atar Chicken Bulghur Bowls",
#  "Baba's Feta Pasta",
#  "Grands-pères au sirop d'érable (Maple Dumplings)",
#  'Fajita Seasoning',
#  'Scouse',
#  "Shepherd's Pie",
#  'Glühwein - mulled wine',
#  'Honey Vanilla Ice Cream',
#  'Long-cooked Chuck Steak With Vegetables',
#  'Shrimp and Chicken Jambalaya',
#  'Arroz Chaufa',
#  'Mushroom risotto',
#  'Simple Chicken Curry',
#  'Hamburger Patties',
#  'Hearty Breakfast Oatmeal',
#  'Pasta (store bought)',
#  'Quesadilla',
#  'Spaghetti and Meatballs',
#  'Belgian pear syrup',
#  'Aljotta',
#  'Banana and oatmeal cookies',
#  'Chicken Tenders Airfried',
#  'Älplermagronen (Alpine macaroni)',
#  'Rice',
#  'Coleslaw',
#  'Chicken in Red Wine Vinegar Sauce',
#  'Stoofvlees',
#  'No-knead pizza dough',
#  'Apple Pie',
#  'Pastítsio',
#  'Roasted chicken breast',
#  'Japanese Noodle Soup',
#  'Taco Meat',
#  'Crab salad',
#  'Tarta de Santiago',
#  'Zarangollo',
#  'Chicken Tikka Masala',
#  'Bolinhos de Coco',
#  'Challah Bread',
#  'Red Lentil Dahl',
#  'Sardine Cakes',
#  'Potato and Eggplant (Aubergine) Curry',
#  'Yogurt',
#  'Smoked Salmon Quiche',
#  'Tomato and Grilled Bell Pepper soup',
#  'Simple Tuna Salad',
#  'Chocolate Chip Cookies',
#  "Merchant's Buckwheat",
#  'Autumn Soup',
#  'Bolo do Caco (Caco Bread)',
#  'Greek Easter Cookies',
#  'Scandinavian Coffee Cake',
#  'Brigadeiro',
#  'Tarte Merengada de Limão',
#  'Sourdough starter',
#  'Chicken Satay with Peanut Sauce',
#  'Cacio e Pepe',
#  'Chicken, Tomato and Spinach Curry',
#  'Ratatouille',
#  'Miso Ginger Pork',
#  'Ceviche',
#  'Marinated pork steaks',
#  'Spicy Sausage Pasta',
#  'Pan pizza',
#  'Hoisin Tofu and Broccoli',
#  'Curry sauce',
#  'Garlic Toast',
#  'Pozharskiye Cutlets',
#  'Lobster bisque',
#  "Spaghetti all'amatriciana",
#  'Yorkshire Puddings',
#  'Sopa de Lentejas',
#  'Spicy Kung Pao-Style Chicken',
#  'Collard Greens with Smoked Duck and Parsnips',
#  'Ricotta lasagna filling',
#  'Simple Creamy Pasta Sauce',
#  'Cheddar-Crusted Chicken',
#  'Colcannon Bake',
#  'Bolognese Sauce',
#  'Chilli con Carne',
#  'Full English Breakfast',
#  'Cooked Chickpeas',
#  'Lemon juice salad dressing',
#  'Country Breakfast Skillet',
#  'Oats',
#  'Savory Squash',
#  'Turkish Yogurt Soup',
#  'Orange jam',
#  'Erwtensoep (Dutch pea soup)',
#  'Grostoli',
#  'Ukrainian Borscht',
#  'Pulpo a la gallega',
#  'Pavlova',
#  'Stuffed Round Squash',
#  'Chicken Wings',
#  'Croutons',
#  'French Toast',
#  'Dulce de Leche',
#  'Flammkuchen',
#  'Tofu and Cashew Chow Mein',
#  'Kettle Corn',
#  'Fajitas',
#  'Kropsua (Finnish Baked Pancake)',
#  'Hummus',
#  'Salsa',
#  'Lenten Lentil Curry',
#  'Breakfast Wrap',
#  'Peanut Butter',
#  'Traditional beef or lamb stew',
#  'Wholemeal Pizza',
#  'Chicken Paprikash',
#  'Liver Pate',
#  'Irish Coffee',
#  'Honey Garlic Chicken with Broccoli and Brown Rice',
#  'Galinha Caipira',
#  "Tuh'u",
#  'Tuna Sub',
#  'Fried Potatoes',
#  'Fish Curry',
#  'Oaty Pancakes',
#  'Simple sauce',
#  'Basic Meatballs',
#  'Instant Tom Yam Kung noodle soup',
#  'Baby Back Ribs',
#  'Fondue',
#  'Garam Masala',
#  'Crème brûlée',
#  "Dianne's Southwestern Cornbread Salad",
#  'Pickled Red Onions',
#  'Chicken Stock or Bone Broth',
#  'Pasta sauce',
#  'Pasta Alla Norma',
#  'Turkish Red Lentil Soup',
#  'Broccoli with Ginger and Garlic Sauce',
#  'Cream Cheese',
#  'Stir Fried Chicken with an Orange Sauce',
#  'Banana Muffins with Chocolate',
#  'Fennel White Bean and Kale Soup',
#  'Assam Tea',
#  'Egyptian Lentils',
#  'Greek Salad',
#  'Tunisian Couscous',
#  'Lemon and oregano chicken traybake',
#  'Sauerkraut',
#  'Lamb Biriyani',
#  'Grilled Mackerel with Miso Soup and Squash',
#  'Kalderetang Manok',
#  'Mazurek',
#  'Quick Breakfast Spaghetti',
#  'Coconut Oil Coffee',
#  'Breton Crêpes (Breton Galettes)',
#  'Brown Sauce',
#  "Ray Peat's Carrot Salad",
#  'Tortellini',
#  'Sunday Morning Milkshake',
#  'Butter Chicken Masala Curry',
#  'Farcies tomatoes',
#  'Tzatziki',
#  'Hellfire Steak',
#  'Dominican Spaghetti',
#  'Corn Salsa',
#  'Granola',
#  'Spaghetti alla puttanesca',
#  'Maque Choux',
#  'Ketchup',
#  'One-Pot Chicken Tetrazzini',
#  'Russian Okroshka',
#  'Chimichanga',
#  'Chicken Pasta Casserole',
#  'Cannellini Bean Salad',
#  'Lavacake',
#  'No-knead Bread',
#  'Cinque Pi',
#  'Exotic Ginger Cumin Chicken',
#  'Chicken Biscuit Potpie Recipe',
#  "'Tahini short bread'",
#  'Pasta Navy Style',
#  'Francesinha',
#  'Beef Kidney',
#  'Turkish-Style Spiced Chicken',
#  'Hamburger dressing',
#  'Baked Mostaccioli',
#  'Slow-cooked Pork Carnitas',
#  'Apple strudel',
#  'Gnocchi',
#  'Party Mimosa',
#  'Schnitzel',
#  'Pâté Chinois (Quebec Style Shepherd’s Pie)',
#  'French Onion Soup',
#  'Broiled Trevally',
#  'Mayonnaise or aioli',
#  'Paneer Tikka Masala',
#  'Chicken Soup',
#  'Egg Roll in a Bowl',
#  'Meatloaf',
#  'Garlic Butter Seafood Pasta',
#  'Shrimp\xa0and\xa0Sausage\xa0Gumbo',
#  'Hakka-Style Meatballs',
#  'Ardei umpluti with meat',
#  'Spanish Tortilla',
#  'Carbonade Flamande (Traditional Flemish beef stew)',
#  'Orange Glorious',
#  'Perfect Potato Salad',
#  'Demi-glace',
#  'Chicharrones',
#  'Potato Leek Soup',
#  'Lenten Chili',
#  'Beef Stroganoff',
#  'Carbonara',
#  'Beef Goulash',
#  'Tajine Maadnous',
#  'Russian 1000 Islands Sauce',
#  'Strawberry Compote',
#  'Bebek Mropol',
#  'Classic béchamel sauce',
#  'Nashville Chicken Sandwich',
#  'Mushroom Stroganov',
#  'Coriander Chicken',
#  'Banana Bread',
#  'Puff Pastry',
#  'Banana Pancakes',
#  'Pizza Dough',
#  'Potato sourdough bread',
#  'Sausage Rolls',
#  'Tiroler Gröstl',
#  'Newfoundland Cod Chowder',
#  'Zaatar']

# %%
df[df["title"] == 'French Crêpes']
# Out:
#             title       date                                      tags  \
# 83  French Crêpes 2021-03-14  [french, dessert, breakfast, cheesefare]
#
#                                 introduction  \
# 83  Like pancakes, but very thin. 15 crêpes.
#
#                                           ingredients  \
# 83  - 300g white flour - 3 eggs - 60cl milk - 20cl...
#
#                                             direction  \
# 83  1. Mix flour, salt, eggs and melted butter or ...
#
#                                                output  ingredients_count  \
# 83  {'title': 'French Crêpes', 'ingredients': '- 3...                 23
#
#     direction_count
# 83              138

# %%
df["title"][83]
# Out:
# 'French Crêpes'

# %%
output = await recipe_parser.run(ingredients=df["ingredients"][83], steps=df["direction"][83])
output
# Out:
# Recipe(name='Crêpes', serving_size=4, ingredients=[Ingredient(id=1, name='white flour', quantity=300.0, unit='g'), Ingredient(id=2, name='eggs', quantity=3.0, unit='unit'), Ingredient(id=3, name='milk', quantity=60.0, unit='cl'), Ingredient(id=4, name='beer', quantity=20.0, unit='cl'), Ingredient(id=5, name='butter', quantity=30.0, unit='g')], steps=[Step(number=1, description='Mix flour, eggs, and melted butter in a bowl.', preparation_time=None, cooking_time=None, used_ingredients=[1, 2, 5]), Step(number=2, description='Slowly add milk and beer until the dough becomes fluid enough.', preparation_time=5, cooking_time=None, used_ingredients=[3, 4]), Step(number=3, description='Let the dough rest for one hour.', preparation_time=60, cooking_time=None, used_ingredients=[]), Step(number=4, description='Cook the crêpe in a flat pan, one ladle at a time.', preparation_time=10, cooking_time=None, used_ingredients=[])], total_preparation_time=None, total_cooking_time=None, comments=['Oil the pan frequently with an oiled piece of fabric.', 'Wait for the pan to be hot before cooking the first crêpe.', 'Wait until the crêpe has dried up to flip it.', 'When pouring the dough, follow the pan rotation with the ladle to evenly spread a thin layer of it.'])

# %%
french_crepe = output.model_dump(mode="json")
french_crepe
# Out:
# {'name': 'Crêpes',
#  'serving_size': 4,
#  'ingredients': [{'id': 1,
#    'name': 'white flour',
#    'quantity': 300.0,
#    'unit': 'g'},
#   {'id': 2, 'name': 'eggs', 'quantity': 3.0, 'unit': 'unit'},
#   {'id': 3, 'name': 'milk', 'quantity': 60.0, 'unit': 'cl'},
#   {'id': 4, 'name': 'beer', 'quantity': 20.0, 'unit': 'cl'},
#   {'id': 5, 'name': 'butter', 'quantity': 30.0, 'unit': 'g'}],
#  'steps': [{'number': 1,
#    'description': 'Mix flour, eggs, and melted butter in a bowl.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [1, 2, 5]},
#   {'number': 2,
#    'description': 'Slowly add milk and beer until the dough becomes fluid enough.',
#    'preparation_time': 5,
#    'cooking_time': None,
#    'used_ingredients': [3, 4]},
#   {'number': 3,
#    'description': 'Let the dough rest for one hour.',
#    'preparation_time': 60,
#    'cooking_time': None,
#    'used_ingredients': []},
#   {'number': 4,
#    'description': 'Cook the crêpe in a flat pan, one ladle at a time.',
#    'preparation_time': 10,
#    'cooking_time': None,
#    'used_ingredients': []}],
#  'total_preparation_time': None,
#  'total_cooking_time': None,
#  'comments': ['Oil the pan frequently with an oiled piece of fabric.',
#   'Wait for the pan to be hot before cooking the first crêpe.',
#   'Wait until the crêpe has dried up to flip it.',
#   'When pouring the dough, follow the pan rotation with the ladle to evenly spread a thin layer of it.']}

# %%
with open("french_crepe.json", "w") as f:
    json.dump(french_crepe, f, ensure_ascii=False, indent=4)

# %%
output.dict()
# Out:
# {'name': 'Loaded Mashed Potatoes',
#  'serving_size': 4,
#  'ingredients': [{'id': 1,
#    'name': 'potatoes',
#    'quantity': 1000.0,
#    'unit': 'grams'},
#   {'id': 2, 'name': 'milk', 'quantity': 200.0, 'unit': 'milliliters'},
#   {'id': 3, 'name': 'mayonnaise', 'quantity': 200.0, 'unit': 'milliliters'},
#   {'id': 4, 'name': 'cheese', 'quantity': 100.0, 'unit': 'grams'},
#   {'id': 5, 'name': 'garlic powder', 'quantity': None, 'unit': None},
#   {'id': 6, 'name': 'bacon', 'quantity': 12.0, 'unit': 'strips'},
#   {'id': 7, 'name': 'butter', 'quantity': None, 'unit': None},
#   {'id': 8, 'name': 'green onions', 'quantity': None, 'unit': None},
#   {'id': 9, 'name': 'black pepper', 'quantity': None, 'unit': None},
#   {'id': 10, 'name': 'salt', 'quantity': None, 'unit': None}],
#  'steps': [{'number': 1,
#    'description': 'Peel and cut the potatoes into medium-sized pieces.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [1]},
#   {'number': 2,
#    'description': 'Put the potatoes in a pot with some water so that it covers the potatoes and boil them for about 20-30 minutes, or until the potatoes are soft.',
#    'preparation_time': None,
#    'cooking_time': 20,
#    'used_ingredients': [1]},
#   {'number': 3,
#    'description': 'About ten minutes before removing the potatoes from the boiling water, cut the bacon into little pieces and fry it.',
#    'preparation_time': None,
#    'cooking_time': 10,
#    'used_ingredients': [6]},
#   {'number': 4,
#    'description': 'Warm up the milk and mayonnaise.',
#    'preparation_time': 2,
#    'cooking_time': None,
#    'used_ingredients': [2, 3]},
#   {'number': 5,
#    'description': 'Shred the cheese.',
#    'preparation_time': 2,
#    'cooking_time': None,
#    'used_ingredients': [4]},
#   {'number': 6,
#    'description': 'When the potatoes are done, remove all water from the pot, add the warm milk and mayonnaise mix, add some butter, and mash with a potato masher or a blender.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [1, 2, 3, 7]},
#   {'number': 7,
#    'description': 'Add some salt, black pepper, and garlic powder to taste and continue mashing the mix.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [5, 9, 10]},
#   {'number': 8,
#    'description': 'Once the mix is somewhat homogeneous and the potatoes are properly mashed, add the shredded cheese and fried bacon and mix a little.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [4, 6]},
#   {'number': 9,
#    'description': 'Serve and top with chopped green onions.',
#    'preparation_time': None,
#    'cooking_time': None,
#    'used_ingredients': [8]}],
#  'total_preparation_time': 14,
#  'total_cooking_time': 30,
#  'comments': ['You can play with the proportions depending on how creamy or dry you want the mashed potatoes to be.']}

# %%
first_10_recipes = df.head(10)
outputs = [output]

# %%
len(first_10_recipes)
# Out:
# 10

# %%
for i in range(1, len(first_10_recipes)):
    try:
        output = await recipe_parser.run(ingredients=first_10_recipes["ingredients"][i], steps=first_10_recipes["direction"][i])
        outputs.append(output)
    except Exception as e:
        print(f"Error: {e}")
# Out:
# Invalid json output: {
# "name": "Pork Roast with Rosemary and Garlic",
# "serving\_size": 6,
# "ingredients": [
# {"id": 1, "name": "pork roast", "quantity": 1, "unit": "unit"},
# {"id": 2, "name": "fresh rosemary", "quantity": 2, "unit": "tablespoons"},
# {"id": 3, "name": "garlic", "quantity": 8, "unit": "cloves"},
# {"id": 4, "name": "olive oil", "quantity": 0.33, "unit": "cup"},
# {"id": 5, "name": "lemon", "quantity": 1, "unit": "unit"},
# {"id": 6, "name": "pancetta or bacon", "quantity": 4, "unit": "ounces"},
# {"id": 7, "name": "parsley", "quantity": 1, "unit": "teaspoon"}
# ],
# "steps": [
# {"number": 1, "description": "Preheat the oven to 275°F (135°C)"},
# {"number": 2, "description": "Butterfly the pork roast by cutting into three parts and pounding to an even levelness"},
# {"number": 3, "description": "Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil."},
# {"number": 4, "description": "Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher's twine."},
# {"number": 5, "description": "Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part."},
# {"number": 6, "description": "Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper."},
# {"number": 7, "description": "Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette."}
# ],
# "total\_preparation\_time": null,
# "total\_cooking\_time": 120,
# "comments": [
# "Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish."
# ]
# }
# Invalid json output: {
# "name": "Italian Bread",
# "serving\_size": 12,
# "ingredients": [
# {"id": 1, "name": "bread flour", "quantity": 600, "unit": "g"},
# {"id": 2, "name": "active dry yeast", "quantity": 2.25, "unit": "tsp"},
# {"id": 3, "name": "water", "quantity": 400, "unit": "g"},
# {"id": 4, "name": "salt", "quantity": 12, "unit": "g"}
# ],
# "steps": [
# {"number": 1, "description": "Activate yeast in a bowl with some water", "preparation\_time": 10},
# {"number": 2, "description": "Add the remaining water and optionally the salt", "preparation\_time": 5},
# {"number": 3, "description": "Slowly mix in flour until a smooth dough forms", "preparation\_time": 10},
# {"number": 4, "description": "Let the dough rest for 15 minutes", "preparation\_time": 15},
# {"number": 5, "description": "Knead the dough and let it rise for 1 hour", "preparation\_time": 5},
# {"number": 6, "description": "Split the dough in half and shape into two loaves", "preparation\_time": 10},
# {"number": 7, "description": "Let the loaves rise for 1 hour", "preparation\_time": 60},
# {"number": 8, "description": "Preheat the oven to 200°C (400°F)", "preparation\_time": 10},
# {"number": 9, "description": "Score the loaves and bake for 25-30 minutes", "cooking\_time": 25},
# {"number": 10, "description": "Let the loaves cool for 15 minutes before serving", "preparation\_time": 15}
# ],
# "total\_preparation\_time": 170,
# "total\_cooking\_time": 25,
# "comments": ["Unsalted bread is normal in Central Italy, but it's an acquired taste"]
# }
#
# Note: The quantity of water in step 2 is calculated as the total water required (400g) minus the amount used to activate the yeast. In the original instructions, it is not specified how much water is used to activate the yeast, so I assumed a small amount (e.g. 50g). If the actual amount used is different, the quantity of water in step 2 should be adjusted accordingly. Also, the conversion from grams to teaspoons for the salt is approximate and may vary depending on the type of salt used.

# %%
outputs
# Out:
# [Recipe(name='Loaded Mashed Potatoes', serving_size=4, ingredients=[Ingredient(id=1, name='potatoes', quantity=1000.0, unit='grams'), Ingredient(id=2, name='milk', quantity=200.0, unit='milliliters'), Ingredient(id=3, name='mayonnaise', quantity=200.0, unit='milliliters'), Ingredient(id=4, name='cheese', quantity=100.0, unit='grams'), Ingredient(id=5, name='garlic powder', quantity=None, unit=None), Ingredient(id=6, name='bacon', quantity=12.0, unit='strips'), Ingredient(id=7, name='butter', quantity=None, unit=None), Ingredient(id=8, name='green onions', quantity=None, unit=None), Ingredient(id=9, name='black pepper', quantity=None, unit=None), Ingredient(id=10, name='salt', quantity=None, unit=None)], steps=[Step(number=1, description='Peel and cut the potatoes into medium-sized pieces.', preparation_time=None, cooking_time=None, used_ingredients=[1]), Step(number=2, description='Put the potatoes in a pot with some water so that it covers the potatoes and boil them for about 20-30 minutes, or until the potatoes are soft.', preparation_time=None, cooking_time=20, used_ingredients=[1]), Step(number=3, description='About ten minutes before removing the potatoes from the boiling water, cut the bacon into little pieces and fry it.', preparation_time=None, cooking_time=10, used_ingredients=[6]), Step(number=4, description='Warm up the milk and mayonnaise.', preparation_time=2, cooking_time=None, used_ingredients=[2, 3]), Step(number=5, description='Shred the cheese.', preparation_time=2, cooking_time=None, used_ingredients=[4]), Step(number=6, description='When the potatoes are done, remove all water from the pot, add the warm milk and mayonnaise mix, add some butter, and mash with a potato masher or a blender.', preparation_time=None, cooking_time=None, used_ingredients=[1, 2, 3, 7]), Step(number=7, description='Add some salt, black pepper, and garlic powder to taste and continue mashing the mix.', preparation_time=None, cooking_time=None, used_ingredients=[5, 9, 10]), Step(number=8, description='Once the mix is somewhat homogeneous and the potatoes are properly mashed, add the shredded cheese and fried bacon and mix a little.', preparation_time=None, cooking_time=None, used_ingredients=[4, 6]), Step(number=9, description='Serve and top with chopped green onions.', preparation_time=None, cooking_time=None, used_ingredients=[8])], total_preparation_time=14, total_cooking_time=30, comments=['You can play with the proportions depending on how creamy or dry you want the mashed potatoes to be.']),
#  Recipe(name='Chili con Carne', serving_size=6, ingredients=[Ingredient(id=1, name='salt pork', quantity=130.0, unit='g'), Ingredient(id=2, name='chuck roast', quantity=907.18, unit='g'), Ingredient(id=3, name='garlic', quantity=3.0, unit='cloves'), Ingredient(id=4, name='crushed hot red pepper', quantity=None, unit=None), Ingredient(id=5, name='sweet onion', quantity=1.0, unit=None), Ingredient(id=6, name='large carrot', quantity=1.0, unit=None), Ingredient(id=7, name='bay leaves', quantity=2.0, unit=None), Ingredient(id=8, name='olive oil (or Mazola oil)', quantity=2.0, unit='tablespoons'), Ingredient(id=9, name='tomato paste', quantity=340.19, unit='g'), Ingredient(id=10, name='diced tomatoes', quantity=812.35, unit='g'), Ingredient(id=11, name='tomato puree', quantity=812.35, unit='g')], steps=[Step(number=1, description='Mince the garlic, peel the carrot, peel and cut the onion in half.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=2, description='Pour the oil in a large pot at medium low heat.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=3, description='Chop the salt pork and chuck roast, then simmer in oil with minced garlic.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=4, description='Simmer until the meat has browned.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=5, description='Add the chopped carrot, onion, and tomato paste.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=6, description='Add bay leaves and crushed hot red pepper, then give it a good stir.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=7, description='Lower heat, let simmer for a few hours. Occasionally stir, and add water if sauce gets too thick.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=8, description='Add salt and pepper to taste.', preparation_time=None, cooking_time=None, used_ingredients=[])], total_preparation_time=15, total_cooking_time=180, comments=['Serve with rice or bread.', 'Can be stored in the fridge for up to 3 days or frozen for up to 3 months.']),
#  Recipe(name='Turmeric Flatbread', serving_size=4, ingredients=[Ingredient(id=1, name='wheat flour', quantity=240.0, unit='ml'), Ingredient(id=2, name='ground turmeric', quantity=12.0, unit='ml'), Ingredient(id=3, name='kosher salt', quantity=2.3, unit='ml'), Ingredient(id=4, name='baking powder', quantity=1.2, unit='ml'), Ingredient(id=5, name='olive oil', quantity=28.3, unit='ml'), Ingredient(id=6, name='water', quantity=33.3, unit='ml')], steps=[Step(number=1, description='Combine flour, turmeric, salt and baking powder.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=2, description='Stir in 1/3 cup water and the olive oil.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=3, description='Knead until smooth (1-2 min). Cover and set aside 15 minutes.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=4, description='Cut the dough into 4 pieces; flatten each into a 6-inch round.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=5, description='Cook one at a time in an oiled skillet over medium-high heat, flip when browned (2 mins).', preparation_time=None, cooking_time=None, used_ingredients=[])], total_preparation_time=17, total_cooking_time=10, comments=[]),
#  Recipe(name='Swiss Beef and Mushroom Sauce', serving_size=4, ingredients=[Ingredient(id=1, name='beef', quantity=600.0, unit='g'), Ingredient(id=2, name='mushrooms', quantity=250.0, unit='g'), Ingredient(id=3, name='onion', quantity=1.0, unit='unit'), Ingredient(id=4, name='flour', quantity=1.0, unit='tablespoon'), Ingredient(id=5, name='white wine', quantity=200.0, unit='ml'), Ingredient(id=6, name='cream', quantity=200.0, unit='ml'), Ingredient(id=7, name='parsley', quantity=1.0, unit='tablespoon')], steps=[Step(number=1, description='Fry the meat in butter at high heat until it starts loosing liquid.', preparation_time=None, cooking_time=None, used_ingredients=[1]), Step(number=2, description='Take the meat out of the pan and set aside.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=3, description='Saute the onions.', preparation_time=None, cooking_time=None, used_ingredients=[3]), Step(number=4, description='Add the mushrooms, saute, then add a tbsp of flour and mix well. The flour will make the sauce thicker, so use carfully.', preparation_time=None, cooking_time=None, used_ingredients=[2, 4]), Step(number=5, description='Add the white wine and let it boil for a few minutes.', preparation_time=None, cooking_time=None, used_ingredients=[5]), Step(number=6, description='Add cream, boil until the sauce is very creamy.', preparation_time=None, cooking_time=None, used_ingredients=[6]), Step(number=7, description='Add the meat, boil until the meat is warm.', preparation_time=None, cooking_time=None, used_ingredients=[1]), Step(number=8, description='Add parsley, and serve.', preparation_time=None, cooking_time=None, used_ingredients=[7])], total_preparation_time=None, total_cooking_time=None, comments=['Serve with Rösti or other traditional Swiss dish.']),
#  '{\n"name": "Pork Roast with Rosemary and Garlic",\n"serving\\_size": 6,\n"ingredients": [\n{"id": 1, "name": "pork roast", "quantity": 1, "unit": "unit"},\n{"id": 2, "name": "fresh rosemary", "quantity": 2, "unit": "tablespoons"},\n{"id": 3, "name": "garlic", "quantity": 8, "unit": "cloves"},\n{"id": 4, "name": "olive oil", "quantity": 0.33, "unit": "cup"},\n{"id": 5, "name": "lemon", "quantity": 1, "unit": "unit"},\n{"id": 6, "name": "pancetta or bacon", "quantity": 4, "unit": "ounces"},\n{"id": 7, "name": "parsley", "quantity": 1, "unit": "teaspoon"}\n],\n"steps": [\n{"number": 1, "description": "Preheat the oven to 275°F (135°C)"},\n{"number": 2, "description": "Butterfly the pork roast by cutting into three parts and pounding to an even levelness"},\n{"number": 3, "description": "Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil."},\n{"number": 4, "description": "Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher\'s twine."},\n{"number": 5, "description": "Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part."},\n{"number": 6, "description": "Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper."},\n{"number": 7, "description": "Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette."}\n],\n"total\\_preparation\\_time": null,\n"total\\_cooking\\_time": 120,\n"comments": [\n"Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish."\n]\n}',
#  Recipe(name='Smoked Salmon Pasta Primavera', serving_size=4, ingredients=[Ingredient(id=1, name='Linguine', quantity=12.0, unit='oz'), Ingredient(id=2, name='Asparagus', quantity=0.5, unit='lb'), Ingredient(id=3, name='Green Beans', quantity=0.25, unit='lb'), Ingredient(id=4, name='Sugar Snap Peas', quantity=0.5, unit='cup'), Ingredient(id=5, name='Edamame or Peas', quantity=0.5, unit='cup'), Ingredient(id=6, name='Butter', quantity=1.0, unit='Tbsp'), Ingredient(id=7, name='Onion', quantity=1.0, unit='small'), Ingredient(id=8, name='Garlic', quantity=2.0, unit='cloves'), Ingredient(id=9, name='All-Purpose Flour', quantity=3.0, unit='Tbsp'), Ingredient(id=10, name='Milk', quantity=2.5, unit='cup'), Ingredient(id=11, name='Smoked Salmon', quantity=0.375, unit='lb'), Ingredient(id=12, name='Fresh Mint', quantity=0.5, unit='cup'), Ingredient(id=13, name='Lemon', quantity=0.5, unit='unit')], steps=[Step(number=1, description='In a large pot of boiling salted water, cook linguine 10 min or until al dente, adding asparagus, beans, and sugar snap peas during the last 3 minutes of cooking and edamame during the last minute. Drain very well.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=2, description='Meanwhile in large saucepan, melt butter over medium heat. Add onion and garlic; cook, stirring 3 minutes. Stir in flour. Very gradually whisk in milk until smooth and stir often until mixture boils and has thickened (5 mins).', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=3, description='Add pasta mixture, stirring until hot. Stir in salmon and mint just until mixed. Squeeze juice from lemon into pasta and stir.', preparation_time=None, cooking_time=None, used_ingredients=[])], total_preparation_time=10, total_cooking_time=25, comments=[]),
#  Recipe(name='Spicy Chili Mayonnaise', serving_size=None, ingredients=[Ingredient(id=1, name='mayonnaise', quantity=1.0, unit='cup'), Ingredient(id=2, name='chili sauce (e.g Sriracha)', quantity=0.5, unit='cup'), Ingredient(id=3, name='sesame oil', quantity=1.0, unit='tablespoon')], steps=[Step(number=1, description='Add mayonnaise and chili sauce to a bowl.', preparation_time=None, cooking_time=None, used_ingredients=[1, 2]), Step(number=2, description='Add sesame oil to the bowl.', preparation_time=None, cooking_time=None, used_ingredients=[3]), Step(number=3, description='Mix all of the ingredients together.', preparation_time=None, cooking_time=None, used_ingredients=[1, 2, 3]), Step(number=4, description='Taste test it for more chili sauce or mayonnaise.', preparation_time=None, cooking_time=None, used_ingredients=[1, 2])], total_preparation_time=None, total_cooking_time=None, comments=['Note This is just a basic guide, adapt this recipe to your liking.']),
#  Recipe(name='Pama Porridge', serving_size=4, ingredients=[Ingredient(id=1, name='water', quantity=3.0, unit='dl'), Ingredient(id=2, name='Pama porridge rice', quantity=180.0, unit='g'), Ingredient(id=3, name='whole milk', quantity=1000.0, unit='ml'), Ingredient(id=4, name='salt', quantity=2.0, unit='pinches'), Ingredient(id=5, name='sugar', quantity=4.0, unit='tablespoons'), Ingredient(id=6, name='cinnamon', quantity=2.0, unit='teaspoons'), Ingredient(id=7, name='butter', quantity=50.0, unit='g')], steps=[Step(number=1, description='Bring water and rice to a boil in a deep pot. Boil the rice at steady heat and with active stirring for approximately 2 minutes.', preparation_time=2, cooking_time=2, used_ingredients=[1, 2]), Step(number=2, description='Add milk and bring the concoction to a boil. Boil the pot at low heat, still with active stirring for approximately 10 minutes.', preparation_time=None, cooking_time=10, used_ingredients=[3]), Step(number=3, description='Put on lid and boil for approximately 30 minutes. Stir the pot often. If the porridge seems too thin, boil it for another 5-10 minutes.', preparation_time=None, cooking_time=30, used_ingredients=[]), Step(number=4, description='Add salt.', preparation_time=None, cooking_time=None, used_ingredients=[4]), Step(number=5, description='Mix sugar and cinnamon to form cinnamon sugar in a bowl or container.', preparation_time=1, cooking_time=None, used_ingredients=[5, 6]), Step(number=6, description='Serve warm with cinnamon sugar on top and a bit of butter in the middle.', preparation_time=None, cooking_time=None, used_ingredients=[7])], total_preparation_time=3, total_cooking_time=42, comments=[]),
#  Recipe(name='Meat and Rice Stew', serving_size=6, ingredients=[Ingredient(id=1, name='cooking oil', quantity=150.0, unit='ml'), Ingredient(id=2, name='long grain rice', quantity=1000.0, unit='g'), Ingredient(id=3, name='meat', quantity=1500.0, unit='g'), Ingredient(id=4, name='onions', quantity=500.0, unit='g'), Ingredient(id=5, name='carrots', quantity=500.0, unit='g'), Ingredient(id=6, name='salt', quantity=2.0, unit='tablespoons'), Ingredient(id=7, name='garlic', quantity=5.0, unit='cloves'), Ingredient(id=8, name='raisins', quantity=None, unit=None), Ingredient(id=9, name='tomato paste', quantity=500.0, unit='ml'), Ingredient(id=10, name='cardamom', quantity=None, unit=None), Ingredient(id=11, name='paprika', quantity=None, unit=None), Ingredient(id=12, name='coriander', quantity=None, unit=None), Ingredient(id=13, name='cinnamon', quantity=None, unit=None), Ingredient(id=14, name='cumin', quantity=None, unit=None), Ingredient(id=15, name='turmeric', quantity=None, unit=None)], steps=[Step(number=1, description='Heat the cooking oil in a cauldron until it is boiling. Add a head of onion and fry until it is black, then throw it out.', preparation_time=None, cooking_time=None, used_ingredients=[1]), Step(number=2, description='Add the coarsely chopped meat and fry until it is golden brown. Add a pinch of salt.', preparation_time=None, cooking_time=None, used_ingredients=[1, 3]), Step(number=3, description='Add the chopped onions and fry for 2 minutes. Add the sliced carrots and fry for another 2 minutes.', preparation_time=None, cooking_time=None, used_ingredients=[1, 4, 5]), Step(number=4, description='Add 500 ml of water diluted with tomato paste and boil for 5 minutes.', preparation_time=None, cooking_time=None, used_ingredients=[1, 9]), Step(number=5, description='Rinse the rice and add it to the cauldron without mixing. Add another 500 ml of water diluted with tomato paste and wait until it is boiling.', preparation_time=None, cooking_time=None, used_ingredients=[2, 9]), Step(number=6, description='Reduce the heat to minimum, add two table spoons of salt and close the cauldron. Leave it on low heat for 1.5-2 hours.', preparation_time=None, cooking_time=None, used_ingredients=[6]), Step(number=7, description='1 hour before it is ready, add the crushed garlic.', preparation_time=None, cooking_time=None, used_ingredients=[7]), Step(number=8, description='If the rice is undercooked, turn it over and add some raisins. Continue boiling until all water is evaporated.', preparation_time=None, cooking_time=None, used_ingredients=[8])], total_preparation_time=None, total_cooking_time=90, comments=[]),
#  '{\n"name": "Italian Bread",\n"serving\\_size": 12,\n"ingredients": [\n{"id": 1, "name": "bread flour", "quantity": 600, "unit": "g"},\n{"id": 2, "name": "active dry yeast", "quantity": 2.25, "unit": "tsp"},\n{"id": 3, "name": "water", "quantity": 400, "unit": "g"},\n{"id": 4, "name": "salt", "quantity": 12, "unit": "g"}\n],\n"steps": [\n{"number": 1, "description": "Activate yeast in a bowl with some water", "preparation\\_time": 10},\n{"number": 2, "description": "Add the remaining water and optionally the salt", "preparation\\_time": 5},\n{"number": 3, "description": "Slowly mix in flour until a smooth dough forms", "preparation\\_time": 10},\n{"number": 4, "description": "Let the dough rest for 15 minutes", "preparation\\_time": 15},\n{"number": 5, "description": "Knead the dough and let it rise for 1 hour", "preparation\\_time": 5},\n{"number": 6, "description": "Split the dough in half and shape into two loaves", "preparation\\_time": 10},\n{"number": 7, "description": "Let the loaves rise for 1 hour", "preparation\\_time": 60},\n{"number": 8, "description": "Preheat the oven to 200°C (400°F)", "preparation\\_time": 10},\n{"number": 9, "description": "Score the loaves and bake for 25-30 minutes", "cooking\\_time": 25},\n{"number": 10, "description": "Let the loaves cool for 15 minutes before serving", "preparation\\_time": 15}\n],\n"total\\_preparation\\_time": 170,\n"total\\_cooking\\_time": 25,\n"comments": ["Unsalted bread is normal in Central Italy, but it\'s an acquired taste"]\n}\n\nNote: The quantity of water in step 2 is calculated as the total water required (400g) minus the amount used to activate the yeast. In the original instructions, it is not specified how much water is used to activate the yeast, so I assumed a small amount (e.g. 50g). If the actual amount used is different, the quantity of water in step 2 should be adjusted accordingly. Also, the conversion from grams to teaspoons for the salt is approximate and may vary depending on the type of salt used.']

# %%
outputs[4]
# Out:
# '{\n"name": "Pork Roast with Rosemary and Garlic",\n"serving\\_size": 6,\n"ingredients": [\n{"id": 1, "name": "pork roast", "quantity": 1, "unit": "unit"},\n{"id": 2, "name": "fresh rosemary", "quantity": 2, "unit": "tablespoons"},\n{"id": 3, "name": "garlic", "quantity": 8, "unit": "cloves"},\n{"id": 4, "name": "olive oil", "quantity": 0.33, "unit": "cup"},\n{"id": 5, "name": "lemon", "quantity": 1, "unit": "unit"},\n{"id": 6, "name": "pancetta or bacon", "quantity": 4, "unit": "ounces"},\n{"id": 7, "name": "parsley", "quantity": 1, "unit": "teaspoon"}\n],\n"steps": [\n{"number": 1, "description": "Preheat the oven to 275°F (135°C)"},\n{"number": 2, "description": "Butterfly the pork roast by cutting into three parts and pounding to an even levelness"},\n{"number": 3, "description": "Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil."},\n{"number": 4, "description": "Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher\'s twine."},\n{"number": 5, "description": "Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part."},\n{"number": 6, "description": "Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper."},\n{"number": 7, "description": "Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette."}\n],\n"total\\_preparation\\_time": null,\n"total\\_cooking\\_time": 120,\n"comments": [\n"Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish."\n]\n}'

# %%
test = outputs[4].replace("\n", "")
test = test.replace("\\", "")
test
# Out:
# '{"name": "Pork Roast with Rosemary and Garlic","serving_size": 6,"ingredients": [{"id": 1, "name": "pork roast", "quantity": 1, "unit": "unit"},{"id": 2, "name": "fresh rosemary", "quantity": 2, "unit": "tablespoons"},{"id": 3, "name": "garlic", "quantity": 8, "unit": "cloves"},{"id": 4, "name": "olive oil", "quantity": 0.33, "unit": "cup"},{"id": 5, "name": "lemon", "quantity": 1, "unit": "unit"},{"id": 6, "name": "pancetta or bacon", "quantity": 4, "unit": "ounces"},{"id": 7, "name": "parsley", "quantity": 1, "unit": "teaspoon"}],"steps": [{"number": 1, "description": "Preheat the oven to 275°F (135°C)"},{"number": 2, "description": "Butterfly the pork roast by cutting into three parts and pounding to an even levelness"},{"number": 3, "description": "Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil."},{"number": 4, "description": "Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher\'s twine."},{"number": 5, "description": "Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part."},{"number": 6, "description": "Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper."},{"number": 7, "description": "Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette."}],"total_preparation_time": null,"total_cooking_time": 120,"comments": ["Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish."]}'

# %%
recipe_doc = json.loads(test)
recipe_doc
# Out:
# {'name': 'Pork Roast with Rosemary and Garlic',
#  'serving_size': 6,
#  'ingredients': [{'id': 1,
#    'name': 'pork roast',
#    'quantity': 1,
#    'unit': 'unit'},
#   {'id': 2, 'name': 'fresh rosemary', 'quantity': 2, 'unit': 'tablespoons'},
#   {'id': 3, 'name': 'garlic', 'quantity': 8, 'unit': 'cloves'},
#   {'id': 4, 'name': 'olive oil', 'quantity': 0.33, 'unit': 'cup'},
#   {'id': 5, 'name': 'lemon', 'quantity': 1, 'unit': 'unit'},
#   {'id': 6, 'name': 'pancetta or bacon', 'quantity': 4, 'unit': 'ounces'},
#   {'id': 7, 'name': 'parsley', 'quantity': 1, 'unit': 'teaspoon'}],
#  'steps': [{'number': 1, 'description': 'Preheat the oven to 275°F (135°C)'},
#   {'number': 2,
#    'description': 'Butterfly the pork roast by cutting into three parts and pounding to an even levelness'},
#   {'number': 3,
#    'description': 'Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil.'},
#   {'number': 4,
#    'description': "Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher's twine."},
#   {'number': 5,
#    'description': 'Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part.'},
#   {'number': 6,
#    'description': 'Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper.'},
#   {'number': 7,
#    'description': 'Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette.'}],
#  'total_preparation_time': None,
#  'total_cooking_time': 120,
#  'comments': ['Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish.']}

# %%
recipe_4 = Recipe(**recipe_doc)

# %%
recipe_4
# Out:
# Recipe(name='Pork Roast with Rosemary and Garlic', serving_size=6, ingredients=[Ingredient(id=1, name='pork roast', quantity=1.0, unit='unit'), Ingredient(id=2, name='fresh rosemary', quantity=2.0, unit='tablespoons'), Ingredient(id=3, name='garlic', quantity=8.0, unit='cloves'), Ingredient(id=4, name='olive oil', quantity=0.33, unit='cup'), Ingredient(id=5, name='lemon', quantity=1.0, unit='unit'), Ingredient(id=6, name='pancetta or bacon', quantity=4.0, unit='ounces'), Ingredient(id=7, name='parsley', quantity=1.0, unit='teaspoon')], steps=[Step(number=1, description='Preheat the oven to 275°F (135°C)', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=2, description='Butterfly the pork roast by cutting into three parts and pounding to an even levelness', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=3, description='Mince the garlic and rosemary and combine with olive oil and lemon zest in a pan. Simmer for 2-3 minutes and strain, reserving the oil.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=4, description="Process the pancetta/bacon and garlic/rosemary mixture in a food processor until smooth. Salt and pepper both sides of the roast and spread the paste over the roast, leaving a 2 inch gap on one side. Roll tightly and secure with butcher's twine.", preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=5, description='Bake at 275°F (135°C) for 2 hours or until internal temperature reaches 135°F (57°C) in the thickest part.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=6, description='Heat olive oil in a cast iron skillet and brown all sides of the pork roast. Juice the lemon into the remaining oil and add parsley, whisking until emulsified. Season with salt and pepper.', preparation_time=None, cooking_time=None, used_ingredients=[]), Step(number=7, description='Slice the roast into 1/2 inch thick slices and top with the lemon herb vinaigrette.', preparation_time=None, cooking_time=None, used_ingredients=[])], total_preparation_time=None, total_cooking_time=120, comments=['Use fresh ingredients for the best flavor. High quality olive oil is important as it is one of the main flavors in this dish.'])

# %%
output_docs = [output.dict() for output in outputs if isinstance(output, Recipe)]

# %%
output_docs
# Out:
# [{'name': 'Loaded Mashed Potatoes',
#   'serving_size': 4,
#   'ingredients': [{'id': 1,
#     'name': 'potatoes',
#     'quantity': 1000.0,
#     'unit': 'grams'},
#    {'id': 2, 'name': 'milk', 'quantity': 200.0, 'unit': 'milliliters'},
#    {'id': 3, 'name': 'mayonnaise', 'quantity': 200.0, 'unit': 'milliliters'},
#    {'id': 4, 'name': 'cheese', 'quantity': 100.0, 'unit': 'grams'},
#    {'id': 5, 'name': 'garlic powder', 'quantity': None, 'unit': None},
#    {'id': 6, 'name': 'bacon', 'quantity': 12.0, 'unit': 'strips'},
#    {'id': 7, 'name': 'butter', 'quantity': None, 'unit': None},
#    {'id': 8, 'name': 'green onions', 'quantity': None, 'unit': None},
#    {'id': 9, 'name': 'black pepper', 'quantity': None, 'unit': None},
#    {'id': 10, 'name': 'salt', 'quantity': None, 'unit': None}],
#   'steps': [{'number': 1,
#     'description': 'Peel and cut the potatoes into medium-sized pieces.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1]},
#    {'number': 2,
#     'description': 'Put the potatoes in a pot with some water so that it covers the potatoes and boil them for about 20-30 minutes, or until the potatoes are soft.',
#     'preparation_time': None,
#     'cooking_time': 20,
#     'used_ingredients': [1]},
#    {'number': 3,
#     'description': 'About ten minutes before removing the potatoes from the boiling water, cut the bacon into little pieces and fry it.',
#     'preparation_time': None,
#     'cooking_time': 10,
#     'used_ingredients': [6]},
#    {'number': 4,
#     'description': 'Warm up the milk and mayonnaise.',
#     'preparation_time': 2,
#     'cooking_time': None,
#     'used_ingredients': [2, 3]},
#    {'number': 5,
#     'description': 'Shred the cheese.',
#     'preparation_time': 2,
#     'cooking_time': None,
#     'used_ingredients': [4]},
#    {'number': 6,
#     'description': 'When the potatoes are done, remove all water from the pot, add the warm milk and mayonnaise mix, add some butter, and mash with a potato masher or a blender.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 2, 3, 7]},
#    {'number': 7,
#     'description': 'Add some salt, black pepper, and garlic powder to taste and continue mashing the mix.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [5, 9, 10]},
#    {'number': 8,
#     'description': 'Once the mix is somewhat homogeneous and the potatoes are properly mashed, add the shredded cheese and fried bacon and mix a little.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [4, 6]},
#    {'number': 9,
#     'description': 'Serve and top with chopped green onions.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [8]}],
#   'total_preparation_time': 14,
#   'total_cooking_time': 30,
#   'comments': ['You can play with the proportions depending on how creamy or dry you want the mashed potatoes to be.']},
#  {'name': 'Chili con Carne',
#   'serving_size': 6,
#   'ingredients': [{'id': 1,
#     'name': 'salt pork',
#     'quantity': 130.0,
#     'unit': 'g'},
#    {'id': 2, 'name': 'chuck roast', 'quantity': 907.18, 'unit': 'g'},
#    {'id': 3, 'name': 'garlic', 'quantity': 3.0, 'unit': 'cloves'},
#    {'id': 4, 'name': 'crushed hot red pepper', 'quantity': None, 'unit': None},
#    {'id': 5, 'name': 'sweet onion', 'quantity': 1.0, 'unit': None},
#    {'id': 6, 'name': 'large carrot', 'quantity': 1.0, 'unit': None},
#    {'id': 7, 'name': 'bay leaves', 'quantity': 2.0, 'unit': None},
#    {'id': 8,
#     'name': 'olive oil (or Mazola oil)',
#     'quantity': 2.0,
#     'unit': 'tablespoons'},
#    {'id': 9, 'name': 'tomato paste', 'quantity': 340.19, 'unit': 'g'},
#    {'id': 10, 'name': 'diced tomatoes', 'quantity': 812.35, 'unit': 'g'},
#    {'id': 11, 'name': 'tomato puree', 'quantity': 812.35, 'unit': 'g'}],
#   'steps': [{'number': 1,
#     'description': 'Mince the garlic, peel the carrot, peel and cut the onion in half.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 2,
#     'description': 'Pour the oil in a large pot at medium low heat.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 3,
#     'description': 'Chop the salt pork and chuck roast, then simmer in oil with minced garlic.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 4,
#     'description': 'Simmer until the meat has browned.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 5,
#     'description': 'Add the chopped carrot, onion, and tomato paste.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 6,
#     'description': 'Add bay leaves and crushed hot red pepper, then give it a good stir.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 7,
#     'description': 'Lower heat, let simmer for a few hours. Occasionally stir, and add water if sauce gets too thick.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 8,
#     'description': 'Add salt and pepper to taste.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []}],
#   'total_preparation_time': 15,
#   'total_cooking_time': 180,
#   'comments': ['Serve with rice or bread.',
#    'Can be stored in the fridge for up to 3 days or frozen for up to 3 months.']},
#  {'name': 'Turmeric Flatbread',
#   'serving_size': 4,
#   'ingredients': [{'id': 1,
#     'name': 'wheat flour',
#     'quantity': 240.0,
#     'unit': 'ml'},
#    {'id': 2, 'name': 'ground turmeric', 'quantity': 12.0, 'unit': 'ml'},
#    {'id': 3, 'name': 'kosher salt', 'quantity': 2.3, 'unit': 'ml'},
#    {'id': 4, 'name': 'baking powder', 'quantity': 1.2, 'unit': 'ml'},
#    {'id': 5, 'name': 'olive oil', 'quantity': 28.3, 'unit': 'ml'},
#    {'id': 6, 'name': 'water', 'quantity': 33.3, 'unit': 'ml'}],
#   'steps': [{'number': 1,
#     'description': 'Combine flour, turmeric, salt and baking powder.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 2,
#     'description': 'Stir in 1/3 cup water and the olive oil.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 3,
#     'description': 'Knead until smooth (1-2 min). Cover and set aside 15 minutes.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 4,
#     'description': 'Cut the dough into 4 pieces; flatten each into a 6-inch round.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 5,
#     'description': 'Cook one at a time in an oiled skillet over medium-high heat, flip when browned (2 mins).',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []}],
#   'total_preparation_time': 17,
#   'total_cooking_time': 10,
#   'comments': []},
#  {'name': 'Swiss Beef and Mushroom Sauce',
#   'serving_size': 4,
#   'ingredients': [{'id': 1, 'name': 'beef', 'quantity': 600.0, 'unit': 'g'},
#    {'id': 2, 'name': 'mushrooms', 'quantity': 250.0, 'unit': 'g'},
#    {'id': 3, 'name': 'onion', 'quantity': 1.0, 'unit': 'unit'},
#    {'id': 4, 'name': 'flour', 'quantity': 1.0, 'unit': 'tablespoon'},
#    {'id': 5, 'name': 'white wine', 'quantity': 200.0, 'unit': 'ml'},
#    {'id': 6, 'name': 'cream', 'quantity': 200.0, 'unit': 'ml'},
#    {'id': 7, 'name': 'parsley', 'quantity': 1.0, 'unit': 'tablespoon'}],
#   'steps': [{'number': 1,
#     'description': 'Fry the meat in butter at high heat until it starts loosing liquid.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1]},
#    {'number': 2,
#     'description': 'Take the meat out of the pan and set aside.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 3,
#     'description': 'Saute the onions.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [3]},
#    {'number': 4,
#     'description': 'Add the mushrooms, saute, then add a tbsp of flour and mix well. The flour will make the sauce thicker, so use carfully.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [2, 4]},
#    {'number': 5,
#     'description': 'Add the white wine and let it boil for a few minutes.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [5]},
#    {'number': 6,
#     'description': 'Add cream, boil until the sauce is very creamy.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [6]},
#    {'number': 7,
#     'description': 'Add the meat, boil until the meat is warm.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1]},
#    {'number': 8,
#     'description': 'Add parsley, and serve.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [7]}],
#   'total_preparation_time': None,
#   'total_cooking_time': None,
#   'comments': ['Serve with Rösti or other traditional Swiss dish.']},
#  {'name': 'Smoked Salmon Pasta Primavera',
#   'serving_size': 4,
#   'ingredients': [{'id': 1,
#     'name': 'Linguine',
#     'quantity': 12.0,
#     'unit': 'oz'},
#    {'id': 2, 'name': 'Asparagus', 'quantity': 0.5, 'unit': 'lb'},
#    {'id': 3, 'name': 'Green Beans', 'quantity': 0.25, 'unit': 'lb'},
#    {'id': 4, 'name': 'Sugar Snap Peas', 'quantity': 0.5, 'unit': 'cup'},
#    {'id': 5, 'name': 'Edamame or Peas', 'quantity': 0.5, 'unit': 'cup'},
#    {'id': 6, 'name': 'Butter', 'quantity': 1.0, 'unit': 'Tbsp'},
#    {'id': 7, 'name': 'Onion', 'quantity': 1.0, 'unit': 'small'},
#    {'id': 8, 'name': 'Garlic', 'quantity': 2.0, 'unit': 'cloves'},
#    {'id': 9, 'name': 'All-Purpose Flour', 'quantity': 3.0, 'unit': 'Tbsp'},
#    {'id': 10, 'name': 'Milk', 'quantity': 2.5, 'unit': 'cup'},
#    {'id': 11, 'name': 'Smoked Salmon', 'quantity': 0.375, 'unit': 'lb'},
#    {'id': 12, 'name': 'Fresh Mint', 'quantity': 0.5, 'unit': 'cup'},
#    {'id': 13, 'name': 'Lemon', 'quantity': 0.5, 'unit': 'unit'}],
#   'steps': [{'number': 1,
#     'description': 'In a large pot of boiling salted water, cook linguine 10 min or until al dente, adding asparagus, beans, and sugar snap peas during the last 3 minutes of cooking and edamame during the last minute. Drain very well.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 2,
#     'description': 'Meanwhile in large saucepan, melt butter over medium heat. Add onion and garlic; cook, stirring 3 minutes. Stir in flour. Very gradually whisk in milk until smooth and stir often until mixture boils and has thickened (5 mins).',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []},
#    {'number': 3,
#     'description': 'Add pasta mixture, stirring until hot. Stir in salmon and mint just until mixed. Squeeze juice from lemon into pasta and stir.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': []}],
#   'total_preparation_time': 10,
#   'total_cooking_time': 25,
#   'comments': []},
#  {'name': 'Spicy Chili Mayonnaise',
#   'serving_size': None,
#   'ingredients': [{'id': 1,
#     'name': 'mayonnaise',
#     'quantity': 1.0,
#     'unit': 'cup'},
#    {'id': 2,
#     'name': 'chili sauce (e.g Sriracha)',
#     'quantity': 0.5,
#     'unit': 'cup'},
#    {'id': 3, 'name': 'sesame oil', 'quantity': 1.0, 'unit': 'tablespoon'}],
#   'steps': [{'number': 1,
#     'description': 'Add mayonnaise and chili sauce to a bowl.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 2]},
#    {'number': 2,
#     'description': 'Add sesame oil to the bowl.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [3]},
#    {'number': 3,
#     'description': 'Mix all of the ingredients together.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 2, 3]},
#    {'number': 4,
#     'description': 'Taste test it for more chili sauce or mayonnaise.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 2]}],
#   'total_preparation_time': None,
#   'total_cooking_time': None,
#   'comments': ['Note This is just a basic guide, adapt this recipe to your liking.']},
#  {'name': 'Pama Porridge',
#   'serving_size': 4,
#   'ingredients': [{'id': 1, 'name': 'water', 'quantity': 3.0, 'unit': 'dl'},
#    {'id': 2, 'name': 'Pama porridge rice', 'quantity': 180.0, 'unit': 'g'},
#    {'id': 3, 'name': 'whole milk', 'quantity': 1000.0, 'unit': 'ml'},
#    {'id': 4, 'name': 'salt', 'quantity': 2.0, 'unit': 'pinches'},
#    {'id': 5, 'name': 'sugar', 'quantity': 4.0, 'unit': 'tablespoons'},
#    {'id': 6, 'name': 'cinnamon', 'quantity': 2.0, 'unit': 'teaspoons'},
#    {'id': 7, 'name': 'butter', 'quantity': 50.0, 'unit': 'g'}],
#   'steps': [{'number': 1,
#     'description': 'Bring water and rice to a boil in a deep pot. Boil the rice at steady heat and with active stirring for approximately 2 minutes.',
#     'preparation_time': 2,
#     'cooking_time': 2,
#     'used_ingredients': [1, 2]},
#    {'number': 2,
#     'description': 'Add milk and bring the concoction to a boil. Boil the pot at low heat, still with active stirring for approximately 10 minutes.',
#     'preparation_time': None,
#     'cooking_time': 10,
#     'used_ingredients': [3]},
#    {'number': 3,
#     'description': 'Put on lid and boil for approximately 30 minutes. Stir the pot often. If the porridge seems too thin, boil it for another 5-10 minutes.',
#     'preparation_time': None,
#     'cooking_time': 30,
#     'used_ingredients': []},
#    {'number': 4,
#     'description': 'Add salt.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [4]},
#    {'number': 5,
#     'description': 'Mix sugar and cinnamon to form cinnamon sugar in a bowl or container.',
#     'preparation_time': 1,
#     'cooking_time': None,
#     'used_ingredients': [5, 6]},
#    {'number': 6,
#     'description': 'Serve warm with cinnamon sugar on top and a bit of butter in the middle.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [7]}],
#   'total_preparation_time': 3,
#   'total_cooking_time': 42,
#   'comments': []},
#  {'name': 'Meat and Rice Stew',
#   'serving_size': 6,
#   'ingredients': [{'id': 1,
#     'name': 'cooking oil',
#     'quantity': 150.0,
#     'unit': 'ml'},
#    {'id': 2, 'name': 'long grain rice', 'quantity': 1000.0, 'unit': 'g'},
#    {'id': 3, 'name': 'meat', 'quantity': 1500.0, 'unit': 'g'},
#    {'id': 4, 'name': 'onions', 'quantity': 500.0, 'unit': 'g'},
#    {'id': 5, 'name': 'carrots', 'quantity': 500.0, 'unit': 'g'},
#    {'id': 6, 'name': 'salt', 'quantity': 2.0, 'unit': 'tablespoons'},
#    {'id': 7, 'name': 'garlic', 'quantity': 5.0, 'unit': 'cloves'},
#    {'id': 8, 'name': 'raisins', 'quantity': None, 'unit': None},
#    {'id': 9, 'name': 'tomato paste', 'quantity': 500.0, 'unit': 'ml'},
#    {'id': 10, 'name': 'cardamom', 'quantity': None, 'unit': None},
#    {'id': 11, 'name': 'paprika', 'quantity': None, 'unit': None},
#    {'id': 12, 'name': 'coriander', 'quantity': None, 'unit': None},
#    {'id': 13, 'name': 'cinnamon', 'quantity': None, 'unit': None},
#    {'id': 14, 'name': 'cumin', 'quantity': None, 'unit': None},
#    {'id': 15, 'name': 'turmeric', 'quantity': None, 'unit': None}],
#   'steps': [{'number': 1,
#     'description': 'Heat the cooking oil in a cauldron until it is boiling. Add a head of onion and fry until it is black, then throw it out.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1]},
#    {'number': 2,
#     'description': 'Add the coarsely chopped meat and fry until it is golden brown. Add a pinch of salt.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 3]},
#    {'number': 3,
#     'description': 'Add the chopped onions and fry for 2 minutes. Add the sliced carrots and fry for another 2 minutes.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 4, 5]},
#    {'number': 4,
#     'description': 'Add 500 ml of water diluted with tomato paste and boil for 5 minutes.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [1, 9]},
#    {'number': 5,
#     'description': 'Rinse the rice and add it to the cauldron without mixing. Add another 500 ml of water diluted with tomato paste and wait until it is boiling.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [2, 9]},
#    {'number': 6,
#     'description': 'Reduce the heat to minimum, add two table spoons of salt and close the cauldron. Leave it on low heat for 1.5-2 hours.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [6]},
#    {'number': 7,
#     'description': '1 hour before it is ready, add the crushed garlic.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [7]},
#    {'number': 8,
#     'description': 'If the rice is undercooked, turn it over and add some raisins. Continue boiling until all water is evaporated.',
#     'preparation_time': None,
#     'cooking_time': None,
#     'used_ingredients': [8]}],
#   'total_preparation_time': None,
#   'total_cooking_time': 90,
#   'comments': []}]

# %%
with open("results.json", "w") as f:
    json.dump(output_docs, f, indent=4)
