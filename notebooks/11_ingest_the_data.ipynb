# %%
import os
import certifi
import json
from pathlib import Path

from dotenv import load_dotenv
from pymongo import MongoClient

# %%
load_dotenv()
# Out:
# True

# %%
MONGODB_SERVER = os.environ.get("MONGODB_SERVER")
assert MONGODB_SERVER, "MONGODB_SERVER is not set"

# %%
mongo_client = MongoClient(MONGODB_SERVER, tlsCAFile=certifi.where())

# %%
db = mongo_client["baker"]
db.list_collection_names()
# Out:
# ['temp', 'recipes']

# %%
path_to_data_folder = Path(os.getcwd()).parent / "data"
path_to_file_to_be_ingested = path_to_data_folder / "output" / "3_standardize_the_data" / "standardized_recipes.json"

# %%
path_to_data_folder.exists(), path_to_file_to_be_ingested.exists()
# Out:
# (True, True)

# %%
with open(path_to_file_to_be_ingested, "r") as file:
    recipes = json.load(file)

# %%
recipes[:3]
# Out:
# [{'id': 0,
#   'title': 'Creamy Mashed Potatoes',
#   'serving_size': 4.0,
#   'preparation_time': None,
#   'cooking_time': None,
#   'date': 1615507200000,
#   'tags': ['potato', 'side', 'cheesefare'],
#   'steps': [{'number': 1,
#     'description': 'Peel and cut the potatoes into medium sized pieces.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [1],
#     'optional': False},
#    {'number': 2,
#     'description': 'Put the potatoes in a pot with some water so that it covers the potatoes and boil them for about 20-30 minutes, or until the potatoes are soft.',
#     'duration': {'preparation': None,
#      'cooking': {'min': 20.0, 'max': 30.0},
#      'waiting': None},
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [1],
#     'optional': False},
#    {'number': 3,
#     'description': 'About ten minutes before removing the potatoes from the boiling water, cut the bacon into little pieces and fry it.',
#     'duration': {'preparation': None, 'cooking': 10.0, 'waiting': None},
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [6],
#     'optional': False},
#    {'number': 4,
#     'description': 'Warm up the milk and mayonnaise.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [2, 3],
#     'optional': False},
#    {'number': 5,
#     'description': 'Shred the cheese.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [4],
#     'optional': True},
#    {'number': 6,
#     'description': 'When the potatoes are done, remove all water from the pot, add the warm milk and mayonnaise mix, add some butter, and mash with a potato masher or a blender.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [1, 2, 3, 7],
#     'optional': True},
#    {'number': 7,
#     'description': 'Add some salt, black pepper and garlic powder to taste and continue mashing the mix.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [9, 10, 5],
#     'optional': True},
#    {'number': 8,
#     'description': 'Once the mix is somewhat homogeneous and the potatoes are properly mashed, add the shredded cheese and fried bacon and mix a little.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [4, 6],
#     'optional': True},
#    {'number': 9,
#     'description': 'Serve and top with chopped green onions.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [8],
#     'optional': False}],
#   'ingredients_source_text': 'The quantities here are for about four adult portions. If you are planning on eating this as a side dish, it might be more like 6-8 portions. * 1kg potatoes * 200ml milk* * 200ml mayonnaise* * ~100g cheese * Garlic powder * 12-16 strips of bacon * Butter * 3-4 green onions * Black pepper * Salt  *You can play with the proportions depending on how creamy or dry you want the mashed potatoes to be.',
#   'directions_source_text': '1. Peel and cut the potatoes into medium sized pieces. 2. Put the potatoes in a pot with some water so that it covers the potatoes and   boil them for about 20-30 minutes, or until the potatoes are soft. 3. About ten minutes before removing the potatoes from the boiling water, cut   the bacon into little pieces and fry it. 4. Warm up the milk and mayonnaise. 5. Shred the cheese. 6. When the potatoes are done, remove all water from the pot, add the warm milk   and mayonnaise mix, add some butter, and mash with a potato masher or a   blender. 7. Add some salt, black pepper and garlic powder to taste and continue mashing   the mix. 8. Once the mix is somewhat homogeneous and the potatoes are properly mashed,   add the shredded cheese and fried bacon and mix a little. 9. Serve and top with chopped green onions.',
#   'ingredients': [{'id': 1,
#     'name': 'potatoes',
#     'quantity': 1.0,
#     'unit': 'kg',
#     'optional': False,
#     'original_unit': 'kilogram',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 2,
#     'name': 'milk',
#     'quantity': 0.2,
#     'unit': 'l',
#     'optional': False,
#     'original_unit': 'ml',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 3,
#     'name': 'mayonnaise',
#     'quantity': 0.2,
#     'unit': 'l',
#     'optional': False,
#     'original_unit': 'ml',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 4,
#     'name': 'cheese',
#     'quantity': 0.1,
#     'unit': 'kg',
#     'optional': True,
#     'original_unit': 'gram',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 5,
#     'name': 'garlic powder',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': True,
#     'original_unit': None,
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 6,
#     'name': 'bacon',
#     'quantity': 14.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'strip',
#     'quantity_min': 12.0,
#     'quantity_max': 16.0},
#    {'id': 7,
#     'name': 'butter',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': True,
#     'original_unit': None,
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 8,
#     'name': 'green onions',
#     'quantity': 3.5,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'unit',
#     'quantity_min': 3.0,
#     'quantity_max': 4.0},
#    {'id': 9,
#     'name': 'black pepper',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': True,
#     'original_unit': None,
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 10,
#     'name': 'salt',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': True,
#     'original_unit': None,
#     'quantity_min': None,
#     'quantity_max': None}]},
#  {'id': 1,
#   'title': "Red Sauce (Ragu all'Italiana)",
#   'serving_size': 7.0,
#   'preparation_time': 12.0,
#   'cooking_time': None,
#   'date': 1615852800000,
#   'tags': ['italian', 'sauce'],
#   'steps': [{'number': 1,
#     'description': 'Mince the garlic, peel the carrot, peel and cut the onion in half.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [3, 5, 6],
#     'optional': False},
#    {'number': 2,
#     'description': 'Pour the oil in a large pot at medium low heat.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': 'medium',
#     'ingredients_ids': [8],
#     'optional': False},
#    {'number': 3,
#     'description': 'Chop the salt pork and chuck roast simmer in oil with garlic.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [1, 2, 3],
#     'optional': False},
#    {'number': 4,
#     'description': 'Simmer until the meat has browned.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [],
#     'optional': False},
#    {'number': 5,
#     'description': 'Add the tomato, full carrot, and onion.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [9, 10, 11, 5, 6],
#     'optional': False},
#    {'number': 6,
#     'description': 'Add bay leaf and red pepper then give it a good stir.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [4, 7],
#     'optional': False},
#    {'number': 7,
#     'description': 'Lower heat let simmer for a few hours.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': 'low',
#     'ingredients_ids': [],
#     'optional': False},
#    {'number': 8,
#     'description': 'Occasionally stir, and add water if sauce gets too thick.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [],
#     'optional': False},
#    {'number': 9,
#     'description': 'Add salt and pepper to taste.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [],
#     'optional': False}],
#   'ingredients_source_text': '- 1/3 lb salt pork - 2 lb chuck roast - 3 Cloves of garlic - Crushed hot red pepper - Sweet onion - Large carrot - 2 Bay leaves - 2 tbsp. Olive oil (she used mazola oil) - 12 oz. Can tomato paste - 29 oz. Diced tomatoes - 29 oz. Tomato puree',
#   'directions_source_text': '1. Mince the garlic, peel the carrot, peel and cut the onion in half. 2. Pour the oil in a large pot at medium low heat. 3. Chop the salt pork and chuck roast simmer in oil with garlic. 4. Simmer until the meat has browned. 5. Add the tomato, full carrot, and onion. 6. Add bay leaf and red pepper then give it a good stir. 7. Lower heat let simmer for a few hours. 8. Occasionally stir, and add water if sauce gets too thick. 9. Add salt and pepper to taste.',
#   'ingredients': [{'id': 1,
#     'name': 'salt pork',
#     'quantity': 0.14968536,
#     'unit': 'kg',
#     'optional': False,
#     'original_unit': 'pound',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 2,
#     'name': 'chuck roast',
#     'quantity': 0.907184,
#     'unit': 'kg',
#     'optional': False,
#     'original_unit': 'pound',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 3,
#     'name': 'garlic',
#     'quantity': 3.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'clove',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 4,
#     'name': 'Crushed hot red pepper',
#     'quantity': 1.0,
#     'unit': 'N/A',
#     'optional': True,
#     'original_unit': 'N/A',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 5,
#     'name': 'Sweet onion',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'unit',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 6,
#     'name': 'Large carrot',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'unit',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 7,
#     'name': 'Bay leaves',
#     'quantity': 2.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'unit',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 8,
#     'name': 'Olive oil',
#     'quantity': 2.0,
#     'unit': 'unit',
#     'optional': True,
#     'original_unit': 'tablespoon',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 9,
#     'name': 'Can tomato paste',
#     'quantity': 12.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'ounce',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 10,
#     'name': 'Diced tomatoes',
#     'quantity': 29.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'ounce',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 11,
#     'name': 'Tomato puree',
#     'quantity': 29.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'ounce',
#     'quantity_min': None,
#     'quantity_max': None}]},
#  {'id': 2,
#   'title': 'Pancake',
#   'serving_size': 1.0,
#   'preparation_time': 20.0,
#   'cooking_time': 10.0,
#   'date': 1615420800000,
#   'tags': ['quick', 'breakfast', 'sweet', 'pancake', 'cheesefare'],
#   'steps': [{'number': 1,
#     'description': 'Mix all ingredients in a bowl.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [1, 2, 3, 4, 5, 6, 7],
#     'optional': False},
#    {'number': 2,
#     'description': 'Let the dough rest for ~15 mins.',
#     'duration': {'preparation': None, 'cooking': None, 'waiting': 15.0},
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [],
#     'optional': False},
#    {'number': 3,
#     'description': 'Heat a pan with a bit butter or oil.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': None,
#     'ingredients_ids': [],
#     'optional': False},
#    {'number': 4,
#     'description': 'For each pancake spread a ladle of dough in the pan and bake them at lower medium temperature until they are brown on both sides.',
#     'duration': None,
#     'temperature': None,
#     'heat_intensity': 'medium',
#     'ingredients_ids': [],
#     'optional': False}],
#   'ingredients_source_text': '- 200g wheat flour or 100g glutenfree flour - 200 ml milk - 2 eggs - 2 tsp sugar - 1 tsp baking soda - a little bit of salt',
#   'directions_source_text': '1. Mix all ingredients in a bowl. 2. Let the dough rest for ~15 mins. 3. Heat a pan with a bit butter or oil. 4. For each pancake spread a ladle of dough in the pan and bake them at lower medium temperature until they are brown on both sides. ## Served with - Syrup - Cinnamon and sugar',
#   'ingredients': [{'id': 1,
#     'name': 'wheat flour',
#     'quantity': 0.2,
#     'unit': 'kg',
#     'optional': False,
#     'original_unit': 'gram',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 2,
#     'name': 'glutenfree flour',
#     'quantity': 0.1,
#     'unit': 'kg',
#     'optional': True,
#     'original_unit': 'gram',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 3,
#     'name': 'milk',
#     'quantity': 0.2,
#     'unit': 'l',
#     'optional': False,
#     'original_unit': 'ml',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 4,
#     'name': 'eggs',
#     'quantity': 2.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'unit',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 5,
#     'name': 'sugar',
#     'quantity': 2.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'teaspoon',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 6,
#     'name': 'baking soda',
#     'quantity': 1.0,
#     'unit': 'unit',
#     'optional': False,
#     'original_unit': 'teaspoon',
#     'quantity_min': None,
#     'quantity_max': None},
#    {'id': 7,
#     'name': 'salt',
#     'quantity': 1.0,
#     'unit': 'N/A',
#     'optional': False,
#     'original_unit': 'N/A',
#     'quantity_min': None,
#     'quantity_max': None}]}]

# %%
db.drop_collection("recipes")
db["recipes"].insert_many(recipes)
# Out:
# InsertManyResult([ObjectId('676a84743ce23983ca097028'), ObjectId('676a84743ce23983ca097029'), ObjectId('676a84743ce23983ca09702a'), ObjectId('676a84743ce23983ca09702b'), ObjectId('676a84743ce23983ca09702c'), ObjectId('676a84743ce23983ca09702d'), ObjectId('676a84743ce23983ca09702e'), ObjectId('676a84743ce23983ca09702f'), ObjectId('676a84743ce23983ca097030'), ObjectId('676a84743ce23983ca097031'), ObjectId('676a84743ce23983ca097032'), ObjectId('676a84743ce23983ca097033'), ObjectId('676a84743ce23983ca097034'), ObjectId('676a84743ce23983ca097035'), ObjectId('676a84743ce23983ca097036'), ObjectId('676a84743ce23983ca097037'), ObjectId('676a84743ce23983ca097038'), ObjectId('676a84743ce23983ca097039'), ObjectId('676a84743ce23983ca09703a'), ObjectId('676a84743ce23983ca09703b'), ObjectId('676a84743ce23983ca09703c'), ObjectId('676a84743ce23983ca09703d'), ObjectId('676a84743ce23983ca09703e'), Ob